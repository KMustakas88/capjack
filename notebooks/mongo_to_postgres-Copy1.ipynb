# %%
import psycopg2
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
uri21 = "mongodb://capdash-restore-21dec:dRYLhMmmtdOcG6i7XJheYgz0gGjZqm7wm4ZYGcRZofmDmRJwMtYeGKZMC2y7viC0XHuPaWqId5xVkmBp0UcEtg==@capdash-restore-21dec.mongo.cosmos.azure.com:10255/?ssl=true&replicaSet=globaldb&retrywrites=false&maxIdleTimeMS=120000&appName=@capdash-restore-21dec@"
uri27 = "mongodb://capdash-restore-27dec:QyQaz0oZJflaLRUQ9q4Pr5q9AT2K9LG8TmYUnDnTKSkgg1VtwMbrDL13DxgxnRiZSA5LLqADJ2UHSHguhHrj8A==@capdash-restore-27dec.mongo.cosmos.azure.com:10255/?ssl=true&replicaSet=globaldb&retrywrites=false&maxIdleTimeMS=120000&appName=@capdash-restore-27dec@"

# %%
# Mongo Database credentials

t_host = "capdash.mongo.cosmos.azure.com"
t_port = "10255" # Mongo port
t_dbname = "capdash-dev"
t_user = "capdash"
t_pw = "BGndB0h2hlKPTNh29JjZRyv9ByYx7pSJ1rXigp79i1OwQJv4YU3yD43NdUzlfLyw0HWzihx7Y1DJzJ047FNHWA=="
# client = MongoClient(f"mongodb://{t_user}:{t_pw}@capdash.mongo.cosmos.azure.com:10255/?tls=true")
client_21 = MongoClient(uri21)
db_mongo21 = client_21.capdash

client_27 = MongoClient(uri27)
db_mongo27 = client_27.capdash
#segments_mongo = db_mongo.segments

#mongo capdash.mongo.cosmos.azure.com:10255/capdash-dev -u capdash -p $cosmos_key --tls -eval 'db.segments.find()' --quiet

# %%
# Inventory2
inv2_dec21 = pd.DataFrame(db_mongo21.inventory2.find())

# %%
inv2_dec21.head()
# Out:
#                         _id                  segment2  year  \
# 0  61a8db4138f958002360a2af  5dbb296113244546a0624174  2016
# 1  61a8db5838f958002360a2b0  5dbb296113244546a0624174  2016
# 2  61a8db5838f958002360a2b1  5dbb296113244546a0624174  2016
# 3  61a8db5838f958002360a2b2  5dbb296113244546a0624174  2016
# 4  61a8db5938f958002360a2b3  5dbb296113244546a0624174  2016
#
#                      sector        value                  customer  \
# 0  5dbb346a13244546a062417a      18484.0  5dbb26b0c657605df515d5e6
# 1  5dbb354d13244546a062417b    2917475.0  5dbb26b0c657605df515d5e6
# 2  5dbb370313244546a062417e        570.0  5dbb26b0c657605df515d5e6
# 3  5f1f088f612f5648c03ebc41  164015449.0  5dbb26b0c657605df515d5e6
# 4  5f1f08ad612f5648c03ebc42    3581387.0  5dbb26b0c657605df515d5e6
#
#       createdAt     updatedAt
# 0  1.638456e+12  1.638456e+12
# 1  1.638456e+12  1.638456e+12
# 2  1.638456e+12  1.638456e+12
# 3  1.638456e+12  1.638456e+12
# 4  1.638456e+12  1.638456e+12

# %%
# Customers
cust_dev21 = pd.DataFrame(db_mongo.customer.find())

# %%
cust_dev21
# Out:
#                          _id     createdAt     updatedAt                  url  \
# 0   5be20bfc85fc4903864420d5  1.541541e+12  1.633690e+12            Montclair
# 1   5d05399b78408d44412e8bac  1.560624e+12  1.571089e+12       Example_City_A
# 2   5dbb26b0c657605df515d5e6  1.572546e+12  1.638215e+12        SouthPasadena
# 3   5e8a981984f4b6216ec03600  1.586141e+12  1.586141e+12      city_of_brawley
# 4   5e8a983584f4b6216ec03601  1.586141e+12  1.586142e+12     city_of_calexico
# 5   5e8a985084f4b6216ec03602  1.586141e+12  1.586142e+12   city_of_calipatria
# 6   5e8a989e84f4b6216ec03603  1.586141e+12  1.586141e+12    city_of_el_centro
# 7   5e8a98b284f4b6216ec03604  1.586141e+12  1.586141e+12    city_of_holtville
# 8   5e8a98e584f4b6216ec03605  1.586141e+12  1.586141e+12     city_of_imperial
# 9   5e8a98f784f4b6216ec03606  1.586141e+12  1.586141e+12  city_of_westmorland
# 10  5e8a990c84f4b6216ec03607  1.586141e+12  1.639608e+12   County_of_Imperial
# ...

# %%
# Out:
# _id           object
# segment2      object
# year           int64
# sector        object
# value        float64
# customer      object
# createdAt    float64
# updatedAt    float64
# dtype: object

# %%
# Inventory2 for dec27
inv2_dec27 = pd.DataFrame(db_mongo27.inventory2.find())

# %%
inv2_dec27[inv2_dec27['_id'].isin(inv2_dec21['_id'])]
# Out:
#                           _id                  segment2  year  \
# 0    61a8db4138f958002360a2af  5dbb296113244546a0624174  2016
# 1    61a8db5838f958002360a2b0  5dbb296113244546a0624174  2016
# 2    61a8db5838f958002360a2b1  5dbb296113244546a0624174  2016
# 3    61a8db5838f958002360a2b2  5dbb296113244546a0624174  2016
# 4    61a8db5938f958002360a2b3  5dbb296113244546a0624174  2016
# ..                        ...                       ...   ...
# 199  61c2456338f958002360a3b1  610998d10582f30021b9b529  2018
# 200  61c2456338f958002360a3b2  610998d10582f30021b9b529  2018
# 201  61c2456338f958002360a3b3  610998d10582f30021b9b529  2018
# 202  61c2456338f958002360a3b4  610998d10582f30021b9b529  2018
# 203  61c2456338f958002360a3b5  610998d10582f30021b9b529  2018
#
#                        sector        value                  customer  \
# 0    5dbb346a13244546a062417a      18484.0  5dbb26b0c657605df515d5e6
# 1    5dbb354d13244546a062417b    2917475.0  5dbb26b0c657605df515d5e6
# ...

# %%
inv2_dec27.shape
# Out:
# (282, 8)

# %%
inv2_dec21.shape
# Out:
# (204, 8)

# %%
left_joined = inv2_dec27.merge(inv2_dec21, on='_id', how='left')

# %%
left_joined[left_joined['segment2_y'].isnull()]
# Out:
#                           _id                segment2_x  year_x  \
# 204  61c4c89e38f958002360a3de  5e8a9e49db49cbe3e077d386    2005
# 205  61c4c89e38f958002360a3df  5e8a9e49db49cbe3e077d386    2005
# 206  61c4c89e38f958002360a3e0  5e8a9e49db49cbe3e077d386    2005
# 207  61c4c89e38f958002360a3e1  5e8a9e49db49cbe3e077d386    2005
# 208  61c4c89e38f958002360a3e2  5e8a9e49db49cbe3e077d386    2005
# ..                        ...                       ...     ...
# 277  61c4d5a238f958002360a45c  5e8a9e49db49cbe3e077d392    2018
# 278  61c4d5a238f958002360a45d  5e8a9e49db49cbe3e077d392    2018
# 279  61c4d5a238f958002360a45e  5e8a9e49db49cbe3e077d392    2018
# 280  61c4d5a238f958002360a45f  5e8a9e49db49cbe3e077d392    2018
# 281  61c4d5a238f958002360a460  5e8a9e49db49cbe3e077d392    2018
#
#                      sector_x      value_x                customer_x  \
# 204  5e8a9e49db49cbe3e077d303  109407230.0  5e8a983584f4b6216ec03601
# ...

# %%
new_custs = left_joined[left_joined['segment2_y'].isnull()].customer_x

# %%
new_custs_df = pd.DataFrame(new_custs)
new

# %%
new_custs_df.merge(cust_dev21, left_on='customer_x', right_on='_id', how='inner')['name'].unique()
# Out:
# array(['City of Calexico', 'City of Calipatria'], dtype=object)
