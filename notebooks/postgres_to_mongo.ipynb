# %%
import psycopg2
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
# Mongo Database credentials

t_host = "capdash.mongo.cosmos.azure.com"
t_port = "10255" # Mongo port
t_dbname = "capdash"
t_user = "capdash"
t_pw = "BGndB0h2hlKPTNh29JjZRyv9ByYx7pSJ1rXigp79i1OwQJv4YU3yD43NdUzlfLyw0HWzihx7Y1DJzJ047FNHWA=="
client = MongoClient(f"mongodb://{t_user}:{t_pw}@capdash.mongo.cosmos.azure.com:10255/?tls=true&retrywrites=false")
db_mongo = client.capdash
#segments_mongo = db_mongo.segments

#mongo capdash.mongo.cosmos.azure.com:10255/capdash-dev -u capdash -p $cosmos_key --tls -eval 'db.segments.find()' --quiet

# %%
inv2 = db_mongo['inventory2']

# %%
dir(inv2)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_indexes',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count',
#  '_count_cmd',
#  '_delete',
#  '_delete_retryable',
#  '_insert',
#  '_insert_one',
#  '_legacy_write',
#  '_map_reduce',
#  '_read_preference_for',
#  '_socket_for_reads',
#  '_socket_for_writes',
#  '_update',
#  '_update_retryable',
#  '_write_concern_for',
#  '_write_concern_for_cmd',
#  'aggregate',
#  'aggregate_raw_batches',
#  'bulk_write',
#  'codec_options',
#  'count',
#  'count_documents',
#  'create_index',
#  'create_indexes',
#  'database',
#  'delete_many',
#  'delete_one',
#  'distinct',
#  'drop',
#  'drop_index',
#  'drop_indexes',
#  'ensure_index',
#  'estimated_document_count',
#  'find',
#  'find_and_modify',
#  'find_one',
#  'find_one_and_delete',
#  'find_one_and_replace',
#  'find_one_and_update',
#  'find_raw_batches',
#  'full_name',
#  'group',
#  'index_information',
#  'initialize_ordered_bulk_op',
#  'initialize_unordered_bulk_op',
#  'inline_map_reduce',
#  'insert',
#  'insert_many',
#  'insert_one',
#  'list_indexes',
#  'map_reduce',
#  'name',
#  'next',
#  'options',
#  'parallel_scan',
#  'read_concern',
#  'read_preference',
#  'reindex',
#  'remove',
#  'rename',
#  'replace_one',
#  'save',
#  'update',
#  'update_many',
#  'update_one',
#  'watch',
#  'with_options',
#  'write_concern']

# %%
mongo_results = segments_mongo.find()

# %%
segs = []
for seg in mongo_results:
    segs.append(seg)

# %%
segs[0]
# Out:
# {'_id': ObjectId('5c985b1ad062fc3182f433ea'),
#  'createdAt': 1553488666421.0,
#  'updatedAt': 1553488666421.0,
#  'name': 'Residential',
#  'combines': None,
#  'totalable': False,
#  'render': False,
#  'customer': ObjectId('5bd4d4d1104fe2139765b165')}

# %%
# get collection names
db_mongo.list_collection_names()
# Out:
# ['measures',
#  'test',
#  'inventory',
#  'content',
#  'sectors',
#  'customer',
#  'factors',
#  'customer_customers_customer__user_customers',
#  'user',
#  'segments',
#  'references',
#  'progress',
#  'inventory2',
#  'actions']

# %%
help(db_mongo.get_collection)
# Out:
# Help on method get_collection in module pymongo.database:
#
# get_collection(name, codec_options=None, read_preference=None, write_concern=None, read_concern=None) method of pymongo.database.Database instance
#     Get a :class:`~pymongo.collection.Collection` with the given name
#     and options.
#
#     Useful for creating a :class:`~pymongo.collection.Collection` with
#     different codec options, read preference, and/or write concern from
#     this :class:`Database`.
#
#       >>> db.read_preference
#       Primary()
#       >>> coll1 = db.test
#       >>> coll1.read_preference
#       Primary()
#       >>> from pymongo import ReadPreference
#       >>> coll2 = db.get_collection(
#       ...     'test', read_preference=ReadPreference.SECONDARY)
#       >>> coll2.read_preference
#       Secondary(tag_sets=None)
#
#     :Parameters:
#       - `name`: The name of the collection - a string.
#       - `codec_options` (optional): An instance of
#         :class:`~bson.codec_options.CodecOptions`. If ``None`` (the
#         default) the :attr:`codec_options` of this :class:`Database` is
#         used.
#       - `read_preference` (optional): The read preference to use. If
#         ``None`` (the default) the :attr:`read_preference` of this
#         :class:`Database` is used. See :mod:`~pymongo.read_preferences`
#         for options.
#       - `write_concern` (optional): An instance of
#         :class:`~pymongo.write_concern.WriteConcern`. If ``None`` (the
#         default) the :attr:`write_concern` of this :class:`Database` is
#         used.
#       - `read_concern` (optional): An instance of
#         :class:`~pymongo.read_concern.ReadConcern`. If ``None`` (the
#         default) the :attr:`read_concern` of this :class:`Database` is
#         used.

# %%
segments_col = db_mongo.get_collection('segments')

# %%
dir(segments_col)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_indexes',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count',
#  '_count_cmd',
#  '_delete',
#  '_delete_retryable',
#  '_insert',
#  '_insert_one',
#  '_legacy_write',
#  '_map_reduce',
#  '_read_preference_for',
#  '_socket_for_reads',
#  '_socket_for_writes',
#  '_update',
#  '_update_retryable',
#  '_write_concern_for',
#  '_write_concern_for_cmd',
#  'aggregate',
#  'aggregate_raw_batches',
#  'bulk_write',
#  'codec_options',
#  'count',
#  'count_documents',
#  'create_index',
#  'create_indexes',
#  'database',
#  'delete_many',
#  'delete_one',
#  'distinct',
#  'drop',
#  'drop_index',
#  'drop_indexes',
#  'ensure_index',
#  'estimated_document_count',
#  'find',
#  'find_and_modify',
#  'find_one',
#  'find_one_and_delete',
#  'find_one_and_replace',
#  'find_one_and_update',
#  'find_raw_batches',
#  'full_name',
#  'group',
#  'index_information',
#  'initialize_ordered_bulk_op',
#  'initialize_unordered_bulk_op',
#  'inline_map_reduce',
#  'insert',
#  'insert_many',
#  'insert_one',
#  'list_indexes',
#  'map_reduce',
#  'name',
#  'next',
#  'options',
#  'parallel_scan',
#  'read_concern',
#  'read_preference',
#  'reindex',
#  'remove',
#  'rename',
#  'replace_one',
#  'save',
#  'update',
#  'update_many',
#  'update_one',
#  'watch',
#  'with_options',
#  'write_concern']

# %%
seg = segments_col.find_one()
seg._id
#segments_col.index_information()
# Out:
# {'_id': ObjectId('5c985b1ad062fc3182f433ea'),
#  'createdAt': 1553488666421.0,
#  'updatedAt': 1553488666421.0,
#  'name': 'Residential',
#  'combines': None,
#  'totalable': False,
#  'render': False,
#  'customer': ObjectId('5bd4d4d1104fe2139765b165')}

# %%
str(seg['_id'])
# Out:
# '5c985b1ad062fc3182f433ea'

# %%
seg.keys()
# Out:
# dict_keys(['_id', 'createdAt', 'updatedAt', 'name', 'combines', 'totalable', 'render', 'customer'])

# %% [markdown]
# # Postgres

# %%
# Postgres Database credentials
t_host = "localhost"
t_port = "5432" # Default postgres port
t_dbname = "capdash"
t_user = "gmustakas"
t_pw = "Kostikey88"
connection = psycopg2.connect(host=t_host, port=t_port, dbname=t_dbname, user=t_user, password=t_pw)
#db_cursor = db_conn.cursor()

cursor = connection.cursor()
postgreSQL_select_Query = "select * from inventory2"

cursor.execute(postgreSQL_select_Query)
inventory = cursor.fetchall()

# %%
inventory
# Out:
# [('ObjectId(5c886d462aa69510522bf3ed)',
#   'Residential',
#   '1.552444742956e+12',
#   '1.553552990876e+12',
#   2008,
#   96213133.63,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886da22aa69510522bf3ee)',
#   'Residential',
#   '1.552444834607e+12',
#   '1.553552993091e+12',
#   2015,
#   98022244.0,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886db12aa69510522bf3ef)',
#   'Residential',
#   '1.552444849019e+12',
#   '1.553552994505e+12',
#   2016,
#   95894119.0,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886dca2aa69510522bf3f0)',
#   'Residential',
#   '1.55244487453e+12',
#   '1.553552995981e+12',
#   2017,
#   91294145.0,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886ddd2aa69510522bf3f1)',
#   'Commercial',
#   '1.552444893252e+12',
#   '1.553552828995e+12',
#   2008,
#   222815803.75,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886df12aa69510522bf3f2)',
#   'Commercial',
#   '1.552444913141e+12',
#   '1.557412561595e+12',
#   2015,
#   201786123.0,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e042aa69510522bf3f3)',
#   'Commercial',
#   '1.552444932093e+12',
#   '1.553552839469e+12',
#   2016,
#   176713562.0,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e152aa69510522bf3f4)',
#   'Commercial',
#   '1.552444949578e+12',
#   '1.557412566025e+12',
#   2017,
#   136765462.0,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e2f2aa69510522bf3f5)',
#   'Municipal',
#   '1.552444975492e+12',
#   '1.553552907931e+12',
#   2008,
#   6148111.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e3c2aa69510522bf3f6)',
#   'Municipal',
#   '1.552444988907e+12',
#   '1.553552909707e+12',
#   2015,
#   5917435.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e492aa69510522bf3f7)',
#   'Municipal',
#   '1.552445001177e+12',
#   '1.553552911543e+12',
#   2016,
#   5848307.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e632aa69510522bf3f8)',
#   'Municipal',
#   '1.552445027831e+12',
#   '1.553552913347e+12',
#   2017,
#   4421703.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e912aa69510522bf3f9)',
#   'Residential',
#   '1.552445073141e+12',
#   '1.553601968102e+12',
#   2008,
#   7774104.39,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886e9f2aa69510522bf3fa)',
#   'Residential',
#   '1.552445087179e+12',
#   '1.553601979136e+12',
#   2015,
#   7211234.0,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886eb52aa69510522bf3fb)',
#   'Residential',
#   '1.55244510968e+12',
#   '1.553602008603e+12',
#   2016,
#   6477914.0,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c886eef2aa69510522bf3fc)',
#   'Residential',
#   '1.552445167293e+12',
#   '1.553602132548e+12',
#   2017,
#   5177222.0,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d0fc2aa69510522bf3fd)',
#   'Commercial',
#   '1.552470268401e+12',
#   '1.55356111276e+12',
#   2008,
#   9194800.7,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d1132aa69510522bf3fe)',
#   'Commercial',
#   '1.552470291663e+12',
#   '1.553561115362e+12',
#   2015,
#   5673121.0,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d1302aa69510522bf3ff)',
#   'Commercial',
#   '1.552470320264e+12',
#   '1.553561119971e+12',
#   2016,
#   3689145.0,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d3ed2aa69510522bf404)',
#   'Community',
#   '1.552471021257e+12',
#   '1.553724027236e+12',
#   2008,
#   31211.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d4042aa69510522bf405)',
#   'Community',
#   '1.552471044921e+12',
#   '1.55372402958e+12',
#   2015,
#   250234.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d41e2aa69510522bf406)',
#   'Community',
#   '1.552471070223e+12',
#   '1.553724105921e+12',
#   2016,
#   20522.36,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d4572aa69510522bf407)',
#   'Community',
#   '1.55247112785e+12',
#   '1.553724108269e+12',
#   2017,
#   17855.22,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d4812aa69510522bf408)',
#   'Municipal',
#   '1.552471169703e+12',
#   '1.553723972044e+12',
#   2008,
#   180.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d4942aa69510522bf409)',
#   'Municipal',
#   '1.552471188239e+12',
#   '1.553723995319e+12',
#   2015,
#   150.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d4a82aa69510522bf40a)',
#   'Municipal',
#   '1.552471208392e+12',
#   '1.553723999256e+12',
#   2016,
#   130.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d4b92aa69510522bf40b)',
#   'Municipal',
#   '1.552471225599e+12',
#   '1.55372400259e+12',
#   2017,
#   120.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d17f2aa69510522bf401)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d5987a6d201387380bf5)',
#   'Community',
#   '1.552471448145e+12',
#   '1.553724110401e+12',
#   2008,
#   970306760.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d5a97a6d201387380bf6)',
#   'Community',
#   '1.552471465955e+12',
#   '1.553724112593e+12',
#   2015,
#   992101544.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d5b87a6d201387380bf7)',
#   'Community',
#   '1.552471480911e+12',
#   '1.553724116329e+12',
#   2016,
#   940384123.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d5c97a6d201387380bf8)',
#   'Community',
#   '1.552471497437e+12',
#   '1.553724118705e+12',
#   2017,
#   880384987.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d6087a6d201387380bf9)',
#   'Municipal',
#   '1.552471560517e+12',
#   '1.553724142317e+12',
#   2008,
#   10123.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d6177a6d201387380bfa)',
#   'Municipal',
#   '1.552471575096e+12',
#   '1.553724148985e+12',
#   2015,
#   94028.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d6317a6d201387380bfb)',
#   'Municipal',
#   '1.552471601398e+12',
#   '1.55372415109e+12',
#   2016,
#   8901.5,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d63f7a6d201387380bfc)',
#   'Municipal',
#   '1.552471615351e+12',
#   '1.553724153253e+12',
#   2017,
#   82333.2,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1992aa69510522bf402)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d64f7a6d201387380bfd)',
#   'Community',
#   '1.552471631151e+12',
#   '1.553724120715e+12',
#   2008,
#   2238350.7,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d6617a6d201387380bfe)',
#   'Community',
#   '1.552471649041e+12',
#   '1.553724122649e+12',
#   2015,
#   1477278.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d6907a6d201387380bff)',
#   'Community',
#   '1.552471696658e+12',
#   '1.553724124835e+12',
#   2016,
#   1718831.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d6e87a6d201387380c01)',
#   'Municipal',
#   '1.552471784301e+12',
#   '1.553724156132e+12',
#   2008,
#   23500.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d71a7a6d201387380c02)',
#   'Community',
#   '1.552471834059e+12',
#   '1.553724126875e+12',
#   2017,
#   1688299.0,
#   'ObjectId(5c985b89d062fc3182f433ed)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d72b7a6d201387380c03)',
#   'Municipal',
#   '1.552471851782e+12',
#   '1.553724158674e+12',
#   2015,
#   22100.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d7447a6d201387380c04)',
#   'Municipal',
#   '1.552471876174e+12',
#   '1.553724164788e+12',
#   2016,
#   20482.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d7557a6d201387380c05)',
#   'Municipal',
#   '1.552471893047e+12',
#   '1.553724167772e+12',
#   2017,
#   18999.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c88d1ba2aa69510522bf403)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d7cd7a6d201387380c06)',
#   'Municipal',
#   '1.552472013599e+12',
#   '1.553601874291e+12',
#   2008,
#   300.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d7e57a6d201387380c07)',
#   'Municipal',
#   '1.552472037708e+12',
#   '1.553601926542e+12',
#   2015,
#   250.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d7f57a6d201387380c08)',
#   'Municipal',
#   '1.552472053826e+12',
#   '1.553601940475e+12',
#   2016,
#   200.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c88d8147a6d201387380c09)',
#   'Municipal',
#   '1.552472084421e+12',
#   '1.553601951084e+12',
#   2017,
#   150.0,
#   'ObjectId(5c985baed062fc3182f433ee)',
#   'ObjectId(5c8869865691810bd8803073)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c929acfbe2c0716905ae347)',
#   'Residential',
#   '1.553111759241e+12',
#   '1.553553005157e+12',
#   2008,
#   4321.0,
#   'ObjectId(5c985b1ad062fc3182f433ea)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5c929ae0be2c0716905ae348)',
#   'Commercial',
#   '1.553111776602e+12',
#   '1.553552861338e+12',
#   2008,
#   22.0,
#   'ObjectId(5c985b22d062fc3182f433eb)',
#   'ObjectId(5c8830e15691810bd8803072)',
#   'ObjectId(5bd4d4d1104fe2139765b165)'),
#  ('ObjectId(5ccfb1d255810f09e581f995)',
#   None,
#   '1.557115346535e+12',
#   '1.559934837489e+12',
#   2016,
#   265831680.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfae7d55810f09e581f989)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb1e755810f09e581f996)',
#   None,
#   '1.557115367056e+12',
#   '1.55715917202e+12',
#   2016,
#   157108729.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfae2555810f09e581f987)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb21f55810f09e581f997)',
#   None,
#   '1.557115423527e+12',
#   '1.557159175599e+12',
#   2016,
#   16346702.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaeb655810f09e581f98a)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb23255810f09e581f998)',
#   None,
#   '1.557115442497e+12',
#   '1.557159178125e+12',
#   2016,
#   35040223.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaef055810f09e581f98b)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb25a55810f09e581f999)',
#   None,
#   '1.557115482077e+12',
#   '1.55715918087e+12',
#   2016,
#   19145016.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfae5755810f09e581f988)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb26d55810f09e581f99a)',
#   None,
#   '1.557115501597e+12',
#   '1.557281055561e+12',
#   2016,
#   96000.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaf8d55810f09e581f98d)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb27c55810f09e581f99b)',
#   None,
#   '1.557115516519e+12',
#   '1.557279040223e+12',
#   2016,
#   4865000.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaf4f55810f09e581f98c)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb6f255810f09e581f9a1)',
#   None,
#   '1.55711665802e+12',
#   '1.55711665802e+12',
#   2005,
#   276908000.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfae7d55810f09e581f989)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb72455810f09e581f9a2)',
#   None,
#   '1.557116708816e+12',
#   '1.557116708816e+12',
#   2005,
#   17207055.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaeb655810f09e581f98a)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb73e55810f09e581f9a3)',
#   None,
#   '1.55711673467e+12',
#   '1.55711673467e+12',
#   2005,
#   163654927.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfae2555810f09e581f987)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb75755810f09e581f9a4)',
#   None,
#   '1.557116759016e+12',
#   '1.557116759016e+12',
#   2005,
#   19942725.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfae5755810f09e581f988)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb77d55810f09e581f9a5)',
#   None,
#   '1.557116797757e+12',
#   '1.557116797757e+12',
#   2005,
#   28258245.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaef055810f09e581f98b)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb78b55810f09e581f9a6)',
#   None,
#   '1.557116811228e+12',
#   '1.557116811228e+12',
#   2005,
#   100000.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaf8d55810f09e581f98d)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5ccfb7b355810f09e581f9a7)',
#   None,
#   '1.557116851238e+12',
#   '1.557116851238e+12',
#   2005,
#   5000000.0,
#   'ObjectId(5ccfb60955810f09e581f99f)',
#   'ObjectId(5ccfaf4f55810f09e581f98c)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5d098b4ff446cc06323ed70f)',
#   None,
#   '1.560906575044e+12',
#   '1.560906575044e+12',
#   2019,
#   5.0,
#   'ObjectId(5d0915f296a2be7df70e975c)',
#   'ObjectId(5ccfae7d55810f09e581f989)',
#   'ObjectId(5ccc789584a3bc7fabfb6ac1)'),
#  ('ObjectId(5d1053c82f78f424355cdbe5)',
#   None,
#   '1.56135111299e+12',
#   '1.602276330592e+12',
#   2005,
#   42861090.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1058632f78f424355cdbf8)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d1053e92f78f424355cdbe6)',
#   None,
#   '1.56135114551e+12',
#   '1.58637098085e+12',
#   2005,
#   6265890.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1057392f78f424355cdbf7)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d1054122f78f424355cdbe7)',
#   None,
#   '1.561351186772e+12',
#   '1.571112374888e+12',
#   2005,
#   689030093.65,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d08cf9c914e3822a614)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d1054262f78f424355cdbe8)',
#   None,
#   '1.561351206121e+12',
#   '1.561351206121e+12',
#   2005,
#   26130.55,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d1ecf9c914e3822a615)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d10543b2f78f424355cdbe9)',
#   None,
#   '1.561351227436e+12',
#   '1.561351227436e+12',
#   2005,
#   36533364.23,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d38cf9c914e3822a616)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d1055632f78f424355cdbee)',
#   None,
#   '1.561351523244e+12',
#   '1.561352325641e+12',
#   2017,
#   38574981.82,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1058632f78f424355cdbf8)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d1055862f78f424355cdbef)',
#   None,
#   '1.561351558661e+12',
#   '1.586370984234e+12',
#   2017,
#   5839301.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1057392f78f424355cdbf7)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d10559f2f78f424355cdbf0)',
#   None,
#   '1.561351583294e+12',
#   '1.57111221388e+12',
#   2017,
#   629030093.65,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d08cf9c914e3822a614)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d1055ac2f78f424355cdbf1)',
#   None,
#   '1.561351596167e+12',
#   '1.561351596167e+12',
#   2017,
#   23517.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d1ecf9c914e3822a615)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5d1055bb2f78f424355cdbf2)',
#   None,
#   '1.561351611143e+12',
#   '1.571107703704e+12',
#   2017,
#   221274002.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d38cf9c914e3822a616)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da4ffb818bbc6738c163dd2)',
#   None,
#   '1.571094456312e+12',
#   '1.571094456312e+12',
#   2005,
#   50986728.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5da4fe7a18bbc6738c163dd1)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da4ffcf18bbc6738c163dd3)',
#   None,
#   '1.571094479862e+12',
#   '1.586370987291e+12',
#   2005,
#   6589284.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5da4fdeb18bbc6738c163dcf)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da4ffe518bbc6738c163dd4)',
#   None,
#   '1.571094501666e+12',
#   '1.571094501666e+12',
#   2017,
#   32829182.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5da4fe7a18bbc6738c163dd1)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da50fb1cfce5b7660955467)',
#   None,
#   '1.571098545192e+12',
#   '1.586370990519e+12',
#   2017,
#   5431230.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5da4fdeb18bbc6738c163dcf)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da52b06cfce5b766095547e)',
#   None,
#   '1.57110554207e+12',
#   '1.571107708953e+12',
#   2017,
#   560001.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d38cf9c914e3822a616)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da5400ddeb41a79f6275261)',
#   None,
#   '1.571110925391e+12',
#   '1.571110925391e+12',
#   2020,
#   34717483.638,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1058632f78f424355cdbf8)',
#   None),
#  ('ObjectId(5da54020deb41a79f6275262)',
#   None,
#   '1.571110944039e+12',
#   '1.571110944039e+12',
#   2020,
#   34553716.362,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1057392f78f424355cdbf7)',
#   None),
#  ('ObjectId(5da54031deb41a79f6275263)',
#   None,
#   '1.571110961828e+12',
#   '1.571110961828e+12',
#   2020,
#   590514375.852,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d08cf9c914e3822a614)',
#   None),
#  ('ObjectId(5da5446fdeb41a79f6275266)',
#   None,
#   '1.571112047409e+12',
#   '1.571112230708e+12',
#   2020,
#   589030093.65,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d08cf9c914e3822a614)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da5446fdeb41a79f6275267)',
#   None,
#   '1.571112047409e+12',
#   '1.571112047409e+12',
#   2020,
#   21165.3,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d1ecf9c914e3822a615)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da5446fdeb41a79f6275268)',
#   None,
#   '1.571112047409e+12',
#   '1.571112047409e+12',
#   2020,
#   199146601.8,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d053d38cf9c914e3822a616)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da5446fdeb41a79f6275269)',
#   None,
#   '1.571112047409e+12',
#   '1.586370993702e+12',
#   2020,
#   5455371.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1057392f78f424355cdbf7)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da5446fdeb41a79f627526a)',
#   None,
#   '1.571112047409e+12',
#   '1.571112047409e+12',
#   2020,
#   34717483.64,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5d1058632f78f424355cdbf8)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da5446fdeb41a79f627526b)',
#   None,
#   '1.571112047409e+12',
#   '1.586371002216e+12',
#   2020,
#   6130355.0,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5da4fdeb18bbc6738c163dcf)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5da5446fdeb41a79f627526c)',
#   None,
#   '1.571112047409e+12',
#   '1.571112047409e+12',
#   2020,
#   29546263.8,
#   'ObjectId(5d0bd489f446cc06323ed710)',
#   'ObjectId(5da4fe7a18bbc6738c163dd1)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5dbb386313244546a0624186)',
#   None,
#   '1.57255075588e+12',
#   '1.597780602158e+12',
#   2016,
#   2917474.59,
#   'ObjectId(5dbb296113244546a0624174)',
#   'ObjectId(5dbb354d13244546a062417b)',
#   'ObjectId(5dbb26b0c657605df515d5e6)'),
#  ('ObjectId(5dbb392413244546a0624187)',
#   None,
#   '1.572550948533e+12',
#   '1.572550948533e+12',
#   2016,
#   570.0,
#   'ObjectId(5dbb296113244546a0624174)',
#   'ObjectId(5dbb370313244546a062417e)',
#   'ObjectId(5dbb26b0c657605df515d5e6)'),
#  ('ObjectId(5dbb39b813244546a0624188)',
#   None,
#   '1.572551096078e+12',
#   '1.572551096078e+12',
#   2016,
#   18484.0,
#   'ObjectId(5dbb296113244546a0624174)',
#   'ObjectId(5dbb346a13244546a062417a)',
#   'ObjectId(5dbb26b0c657605df515d5e6)'),
#  ('ObjectId(5ddd6f8c13244546a0624199)',
#   None,
#   '1.574793100818e+12',
#   '1.574793667402e+12',
#   2017,
#   102051025.0,
#   'ObjectId(5ddd71bb13244546a062419d)',
#   'ObjectId(5ddd6f3d13244546a0624196)',
#   'ObjectId(5c0f1c52ad68e14b37a394a8)'),
#  ('ObjectId(5de5756b5477d56ffb172cf8)',
#   None,
#   '1.575318891539e+12',
#   '1.575322083561e+12',
#   2005,
#   509209.0,
#   'ObjectId(5d797cd32454b16ee295f304)',
#   'ObjectId(5da4fe7a18bbc6738c163dd1)',
#   'ObjectId(5d05399b78408d44412e8bac)'),
#  ('ObjectId(5de6975533c4ab7550d07b9d)',
#   None,
#   '1.575393109424e+12',
#   '1.597780567151e+12',
#   2016,
#   48636.25,
#   'ObjectId(5de696d633c4ab7550d07b99)',
#   'ObjectId(5dbb354d13244546a062417b)',
#   'ObjectId(5dbb26b0c657605df515d5e6)'),
#  ('ObjectId(5e86c17955807b2985617345)',
#   None,
#   '1.58588965712e+12',
#   '1.58588965712e+12',
#   2018,
#   109731390.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87612755807b2985617354)',
#   None,
#   '1.585930535153e+12',
#   '1.585930535153e+12',
#   2018,
#   106145329.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87613755807b2985617355)',
#   None,
#   '1.585930551954e+12',
#   '1.585930551954e+12',
#   2018,
#   20435341.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87614855807b2985617356)',
#   None,
#   '1.585930568022e+12',
#   '1.58593058389e+12',
#   2018,
#   1195424.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8761b755807b2985617357)',
#   None,
#   '1.585930679794e+12',
#   '1.585930679794e+12',
#   2018,
#   4201972.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8761ca55807b2985617358)',
#   None,
#   '1.585930698382e+12',
#   '1.585930698382e+12',
#   2018,
#   2653076.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8761d755807b2985617359)',
#   None,
#   '1.585930711756e+12',
#   '1.585930711756e+12',
#   2018,
#   23218.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8761e755807b298561735a)',
#   None,
#   '1.585930727525e+12',
#   '1.585930727525e+12',
#   2018,
#   3593476.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8761f655807b298561735b)',
#   None,
#   '1.585930742214e+12',
#   '1.585930742214e+12',
#   2018,
#   804.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87620a55807b298561735c)',
#   None,
#   '1.585930762657e+12',
#   '1.585930762657e+12',
#   2018,
#   164015449.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87621455807b298561735d)',
#   None,
#   '1.585930772202e+12',
#   '1.585930772202e+12',
#   2018,
#   3581387.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87622155807b298561735e)',
#   None,
#   '1.585930785418e+12',
#   '1.585930785418e+12',
#   2018,
#   7966.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877c7455807b298561736d)',
#   None,
#   '1.585937524317e+12',
#   '1.585937524317e+12',
#   2012,
#   106492567.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877c9355807b298561736e)',
#   None,
#   '1.585937555034e+12',
#   '1.585937555034e+12',
#   2012,
#   116323128.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877cc555807b298561736f)',
#   None,
#   '1.585937605e+12',
#   '1.585937605e+12',
#   2012,
#   21256549.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877cd355807b2985617370)',
#   None,
#   '1.585937619413e+12',
#   '1.585937619413e+12',
#   2012,
#   1174655.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877ce055807b2985617371)',
#   None,
#   '1.585937632445e+12',
#   '1.585937632445e+12',
#   2012,
#   4010411.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877cf055807b2985617372)',
#   None,
#   '1.585937648718e+12',
#   '1.585937648718e+12',
#   2012,
#   3462304.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877cfc55807b2985617373)',
#   None,
#   '1.585937660037e+12',
#   '1.585937660037e+12',
#   2012,
#   22903.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877d0c55807b2985617374)',
#   None,
#   '1.585937676359e+12',
#   '1.585937676359e+12',
#   2012,
#   4771442.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877d1955807b2985617375)',
#   None,
#   '1.585937689522e+12',
#   '1.585937689522e+12',
#   2012,
#   1067.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877d2655807b2985617376)',
#   None,
#   '1.585937702606e+12',
#   '1.585937702606e+12',
#   2012,
#   150837152.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e877d3755807b2985617377)',
#   None,
#   '1.585937719241e+12',
#   '1.585937719241e+12',
#   2012,
#   3223248.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87891f55807b2985617385)',
#   None,
#   '1.585940767165e+12',
#   '1.585940767165e+12',
#   2012,
#   7185.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87966155807b2985617388)',
#   None,
#   '1.585944161455e+12',
#   '1.585944161455e+12',
#   2005,
#   101523887.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87968455807b2985617389)',
#   None,
#   '1.585944196005e+12',
#   '1.585944196005e+12',
#   2005,
#   121128034.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87969455807b298561738a)',
#   None,
#   '1.585944212777e+12',
#   '1.585944212777e+12',
#   2005,
#   21256549.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8796a355807b298561738b)',
#   None,
#   '1.585944227282e+12',
#   '1.585944227282e+12',
#   2005,
#   1219962.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8796b155807b298561738c)',
#   None,
#   '1.585944241041e+12',
#   '1.585944241041e+12',
#   2005,
#   4515475.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8796bf55807b298561738d)',
#   None,
#   '1.585944255878e+12',
#   '1.585944255878e+12',
#   2005,
#   3094486.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8796d055807b298561738e)',
#   None,
#   '1.585944271945e+12',
#   '1.585944271945e+12',
#   2005,
#   25614.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8796dc55807b298561738f)',
#   None,
#   '1.585944284019e+12',
#   '1.585944284019e+12',
#   2005,
#   5303033.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8796e855807b2985617390)',
#   None,
#   '1.585944296307e+12',
#   '1.585944296307e+12',
#   2005,
#   1186.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8797b355807b2985617391)',
#   None,
#   '1.585944499877e+12',
#   '1.585944499877e+12',
#   2005,
#   120669722.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8797bc55807b2985617392)',
#   None,
#   '1.585944508967e+12',
#   '1.585944508967e+12',
#   2005,
#   2578599.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e8797c855807b2985617393)',
#   None,
#   '1.585944520021e+12',
#   '1.585944520021e+12',
#   2005,
#   5690.0,
#   'ObjectId(5e86c0fe55807b2985617344)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879b3755807b29856173a1)',
#   None,
#   '1.585945399521e+12',
#   '1.585945399521e+12',
#   2018,
#   136817447.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879b4455807b29856173a2)',
#   None,
#   '1.585945412005e+12',
#   '1.585945412005e+12',
#   2018,
#   105565768.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879b5555807b29856173a3)',
#   None,
#   '1.585945429524e+12',
#   '1.585945429524e+12',
#   2018,
#   22918402.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879b6555807b29856173a4)',
#   None,
#   '1.585945444932e+12',
#   '1.585945444932e+12',
#   2018,
#   1510010.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879b7655807b29856173a5)',
#   None,
#   '1.585945462826e+12',
#   '1.585945462826e+12',
#   2018,
#   4253320.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879b8855807b29856173a6)',
#   None,
#   '1.585945480137e+12',
#   '1.585945480137e+12',
#   2018,
#   2835649.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879b9e55807b29856173a7)',
#   None,
#   '1.585945502323e+12',
#   '1.585945502323e+12',
#   2018,
#   26117.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879bac55807b29856173a8)',
#   None,
#   '1.585945516929e+12',
#   '1.585945516929e+12',
#   2018,
#   3894197.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879bc755807b29856173aa)',
#   None,
#   '1.585945543216e+12',
#   '1.585945543216e+12',
#   2018,
#   164015449.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879bdc55807b29856173ab)',
#   None,
#   '1.585945564852e+12',
#   '1.585945564852e+12',
#   2018,
#   3581387.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879c5755807b29856173ad)',
#   None,
#   '1.585945687195e+12',
#   '1.585945687195e+12',
#   2018,
#   871.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e879c8455807b29856173ae)',
#   None,
#   '1.58594573288e+12',
#   '1.58594573288e+12',
#   2018,
#   8406.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a24755807b29856173bc)',
#   None,
#   '1.58594720756e+12',
#   '1.58594720756e+12',
#   2012,
#   116744390.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a25d55807b29856173bd)',
#   None,
#   '1.585947229075e+12',
#   '1.585947229075e+12',
#   2012,
#   98456933.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a26755807b29856173be)',
#   None,
#   '1.585947239723e+12',
#   '1.585947239723e+12',
#   2012,
#   20451704.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a27755807b29856173bf)',
#   None,
#   '1.585947255055e+12',
#   '1.585947255055e+12',
#   2012,
#   1576510.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a28255807b29856173c0)',
#   None,
#   '1.585947266606e+12',
#   '1.585947266606e+12',
#   2012,
#   4160801.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a29755807b29856173c1)',
#   None,
#   '1.585947286976e+12',
#   '1.585947286976e+12',
#   2012,
#   2650162.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a2a355807b29856173c2)',
#   None,
#   '1.585947299433e+12',
#   '1.585947299433e+12',
#   2012,
#   27148.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a2ad55807b29856173c3)',
#   None,
#   '1.585947309762e+12',
#   '1.585947309762e+12',
#   2012,
#   4449640.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a2be55807b29856173c4)',
#   None,
#   '1.585947326505e+12',
#   '1.585947326505e+12',
#   2012,
#   995.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a2c955807b29856173c5)',
#   None,
#   '1.585947337912e+12',
#   '1.585947337912e+12',
#   2012,
#   150837152.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a2dd55807b29856173c6)',
#   None,
#   '1.585947357923e+12',
#   '1.585947357923e+12',
#   2012,
#   3223248.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a2ee55807b29856173c7)',
#   None,
#   '1.585947374122e+12',
#   '1.585947374122e+12',
#   2012,
#   7786.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a45d55807b29856173d4)',
#   None,
#   '1.585947741239e+12',
#   '1.585947741239e+12',
#   2005,
#   106783482.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a47155807b29856173d5)',
#   None,
#   '1.585947761314e+12',
#   '1.585947761314e+12',
#   2005,
#   107472787.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a47d55807b29856173d6)',
#   None,
#   '1.585947773381e+12',
#   '1.585947773381e+12',
#   2005,
#   20451704.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a48c55807b29856173d7)',
#   None,
#   '1.585947787965e+12',
#   '1.585947787965e+12',
#   2005,
#   1642883.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a50255807b29856173d9)',
#   None,
#   '1.585947906551e+12',
#   '1.585947906551e+12',
#   2005,
#   5155885.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a50e55807b29856173da)',
#   None,
#   '1.585947918902e+12',
#   '1.585947918902e+12',
#   2005,
#   2780553.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a51b55807b29856173db)',
#   None,
#   '1.58594793112e+12',
#   '1.58594793112e+12',
#   2005,
#   30530.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a53055807b29856173dc)',
#   None,
#   '1.585947952605e+12',
#   '1.585947952605e+12',
#   2005,
#   5264303.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a53d55807b29856173dd)',
#   None,
#   '1.585947965642e+12',
#   '1.585947965642e+12',
#   2005,
#   1177.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a54d55807b29856173de)',
#   None,
#   '1.585947981318e+12',
#   '1.585956413576e+12',
#   2005,
#   120669722.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a56555807b29856173df)',
#   None,
#   '1.585948005288e+12',
#   '1.585948005288e+12',
#   2005,
#   2578599.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87a57555807b29856173e0)',
#   None,
#   '1.585948021029e+12',
#   '1.585948021029e+12',
#   2005,
#   6726.0,
#   'ObjectId(5e8799fd55807b29856173a0)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87ae9255807b29856173ef)',
#   None,
#   '1.585950354228e+12',
#   '1.585950354228e+12',
#   2018,
#   23418170.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87aea255807b29856173f0)',
#   None,
#   '1.585950370793e+12',
#   '1.585950370793e+12',
#   2018,
#   24958091.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87aeb055807b29856173f1)',
#   None,
#   '1.585950384134e+12',
#   '1.585950384134e+12',
#   2018,
#   4608183.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87aec255807b29856173f2)',
#   None,
#   '1.585950402095e+12',
#   '1.585950402095e+12',
#   2018,
#   140133.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87aed155807b29856173f3)',
#   None,
#   '1.585950417719e+12',
#   '1.585950417719e+12',
#   2018,
#   547711.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87aee455807b29856173f4)',
#   None,
#   '1.585950436604e+12',
#   '1.585950436604e+12',
#   2018,
#   361051.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87aef255807b29856173f5)',
#   None,
#   '1.585950450291e+12',
#   '1.585950450291e+12',
#   2018,
#   1624.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af0055807b29856173f6)',
#   None,
#   '1.585950464081e+12',
#   '1.585950464081e+12',
#   2018,
#   1351637.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af2a55807b29856173f7)',
#   None,
#   '1.585950506111e+12',
#   '1.585950506111e+12',
#   2018,
#   302.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af3655807b29856173f8)',
#   None,
#   '1.585950518149e+12',
#   '1.585956429703e+12',
#   2018,
#   100000000.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af4055807b29856173f9)',
#   None,
#   '1.585950528581e+12',
#   '1.585950528581e+12',
#   2018,
#   3581387.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af4d55807b29856173fa)',
#   None,
#   '1.585950541142e+12',
#   '1.585950541142e+12',
#   2018,
#   1098.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af5a55807b29856173fb)',
#   None,
#   '1.585950554895e+12',
#   '1.585950554895e+12',
#   2012,
#   22233102.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af8355807b29856173fc)',
#   None,
#   '1.585950595085e+12',
#   '1.585950595085e+12',
#   2012,
#   30405045.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af8d55807b29856173fd)',
#   None,
#   '1.585950605473e+12',
#   '1.585950605473e+12',
#   2012,
#   5000076.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87af9d55807b29856173fe)',
#   None,
#   '1.585950621484e+12',
#   '1.585950621484e+12',
#   2012,
#   154560.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87afad55807b29856173ff)',
#   None,
#   '1.585950637553e+12',
#   '1.585950637553e+12',
#   2012,
#   651692.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87afb955807b2985617400)',
#   None,
#   '1.585950649307e+12',
#   '1.585950649307e+12',
#   2012,
#   469126.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87afce55807b2985617401)',
#   None,
#   '1.585950670906e+12',
#   '1.585950670906e+12',
#   2012,
#   2476.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87afdd55807b2985617402)',
#   None,
#   '1.585950685256e+12',
#   '1.585950685256e+12',
#   2012,
#   1241382.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87afeb55807b2985617403)',
#   None,
#   '1.585950699434e+12',
#   '1.585950699434e+12',
#   2012,
#   278.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87aff855807b2985617404)',
#   None,
#   '1.585950712606e+12',
#   '1.585956449373e+12',
#   2012,
#   90000000.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b00855807b2985617405)',
#   None,
#   '1.585950727937e+12',
#   '1.585950727937e+12',
#   2012,
#   3223248.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b01655807b2985617406)',
#   None,
#   '1.585950742684e+12',
#   '1.585950742684e+12',
#   2012,
#   1210.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b02b55807b2985617407)',
#   None,
#   '1.585950763638e+12',
#   '1.585950763638e+12',
#   2005,
#   23418170.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b03b55807b2985617408)',
#   None,
#   '1.585950779816e+12',
#   '1.585950779816e+12',
#   2005,
#   24499721.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b05c55807b2985617409)',
#   None,
#   '1.585950812369e+12',
#   '1.585950812369e+12',
#   2005,
#   4608183.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b06955807b298561740a)',
#   None,
#   '1.585950825705e+12',
#   '1.585950825705e+12',
#   2005,
#   162662.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b07855807b298561740b)',
#   None,
#   '1.585950840752e+12',
#   '1.585950840752e+12',
#   2005,
#   1259806.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b08655807b298561740c)',
#   None,
#   '1.585950854866e+12',
#   '1.585950854866e+12',
#   2005,
#   926245.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b09555807b298561740d)',
#   None,
#   '1.585950869129e+12',
#   '1.585950869129e+12',
#   2005,
#   3974.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b0a155807b298561740e)',
#   None,
#   '1.58595088172e+12',
#   '1.58595088172e+12',
#   2005,
#   1244813.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b0ac55807b298561740f)',
#   None,
#   '1.585950892628e+12',
#   '1.585950892628e+12',
#   2005,
#   278.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e46d6ff55807b2985617327)'),
#  ('ObjectId(5e87b0bd55807b2985617410)',
#   None,
#   '1.585950909599e+12',
#   '1.585956457404e+12',
#   2005,
#   80000000.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875fdb55807b2985617351)',
# ...
#   194015449.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccb8)',
#   None,
#   '1.585962980299e+12',
#   '1.585962980299e+12',
#   2018,
#   4581387.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccb9)',
#   None,
#   '1.585963005516e+12',
#   '1.585963005516e+12',
#   2018,
#   32199.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccba)',
#   None,
#   '1.585963026914e+12',
#   '1.585963026914e+12',
#   2012,
#   110574561.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccbb)',
#   None,
#   '1.585963043231e+12',
#   '1.585963043231e+12',
#   2012,
#   190816768.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccbc)',
#   None,
#   '1.585963056577e+12',
#   '1.585963056577e+12',
#   2012,
#   27997696.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccbd)',
#   None,
#   '1.585963074542e+12',
#   '1.585963074542e+12',
#   2012,
#   16074220.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccbe)',
#   None,
#   '1.585963089564e+12',
#   '1.585963089564e+12',
#   2012,
#   82213430.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccbf)',
#   None,
#   '1.585963105561e+12',
#   '1.585963105561e+12',
#   2012,
#   80595.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc0)',
#   None,
#   '1.585963117425e+12',
#   '1.585963117425e+12',
#   2012,
#   2931459.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc1)',
#   None,
#   '1.585963135739e+12',
#   '1.585963135739e+12',
#   2012,
#   656.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc2)',
#   None,
#   '1.585963163703e+12',
#   '1.585963163703e+12',
#   2012,
#   170837152.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc3)',
#   None,
#   '1.585963193201e+12',
#   '1.585963230224e+12',
#   2012,
#   4023248.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc4)',
#   None,
#   '1.58596325089e+12',
#   '1.58596325089e+12',
#   2012,
#   28469.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc5)',
#   None,
#   '1.585963308375e+12',
#   '1.585963308375e+12',
#   2005,
#   104054441.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc6)',
#   None,
#   '1.585963325364e+12',
#   '1.585963325364e+12',
#   2005,
#   328111388.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc7)',
#   None,
#   '1.585963338095e+12',
#   '1.5859633897e+12',
#   2005,
#   39999602.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc8)',
#   None,
#   '1.585963373203e+12',
#   '1.585963373203e+12',
#   2005,
#   16916810.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccc9)',
#   None,
#   '1.585963407298e+12',
#   '1.585963407298e+12',
#   2005,
#   134204330.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccca)',
#   None,
#   '1.585963419314e+12',
#   '1.585963419314e+12',
#   2005,
#   122975.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cccb)',
#   None,
#   '1.585963435044e+12',
#   '1.585963435044e+12',
#   2005,
#   2612457.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cccc)',
#   None,
#   '1.585963447437e+12',
#   '1.585963447437e+12',
#   2005,
#   584.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cccd)',
#   None,
#   '1.585963463794e+12',
#   '1.585963463794e+12',
#   2005,
#   120669722.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccce)',
#   None,
#   '1.585963491703e+12',
#   '1.585963491703e+12',
#   2005,
#   3078599.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cccf)',
#   None,
#   '1.58596350636e+12',
#   '1.58596350636e+12',
#   2005,
#   28467.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd0)',
#   None,
#   '1.585964545585e+12',
#   '1.585964545585e+12',
#   2018,
#   0.0,
#   'ObjectId(5e87d6ce55807b2985617512)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd1)',
#   None,
#   '1.585964553627e+12',
#   '1.585964553627e+12',
#   2012,
#   0.0,
#   'ObjectId(5e87d6ce55807b2985617512)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd2)',
#   None,
#   '1.585964565207e+12',
#   '1.585964565207e+12',
#   2005,
#   0.0,
#   'ObjectId(5e87d6ce55807b2985617512)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd3)',
#   None,
#   '1.58596458109e+12',
#   '1.58596458109e+12',
#   2018,
#   0.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd4)',
#   None,
#   '1.585964590896e+12',
#   '1.585964590896e+12',
#   2012,
#   0.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd5)',
#   None,
#   '1.585964600736e+12',
#   '1.585964600736e+12',
#   2005,
#   0.0,
#   'ObjectId(5e87de6c55807b2985617558)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd6)',
#   None,
#   '1.58596778854e+12',
#   '1.586030398516e+12',
#   2018,
#   200.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87ef7c55807b29856175ab)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd7)',
#   None,
#   '1.585967834509e+12',
#   '1.586030399654e+12',
#   2012,
#   161.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87ef7c55807b29856175ab)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd8)',
#   None,
#   '1.585967854376e+12',
#   '1.58603040154e+12',
#   2005,
#   115.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87ef7c55807b29856175ab)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccd9)',
#   None,
#   '1.585967896855e+12',
#   '1.585967896855e+12',
#   2018,
#   35725.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccda)',
#   None,
#   '1.585967925538e+12',
#   '1.585967925538e+12',
#   2012,
#   36214.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccdb)',
#   None,
#   '1.585967995021e+12',
#   '1.585967995021e+12',
#   2005,
#   36834.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccdc)',
#   None,
#   '1.585968031098e+12',
#   '1.585968031098e+12',
#   2018,
#   46317.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f0fa55807b29856175ad)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccdd)',
#   None,
#   '1.585968051453e+12',
#   '1.585968051453e+12',
#   2012,
#   49204.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f0fa55807b29856175ad)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccde)',
#   None,
#   '1.585968090116e+12',
#   '1.585968165371e+12',
#   2005,
#   43404.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f0fa55807b29856175ad)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077ccdf)',
#   None,
#   '1.585968325327e+12',
#   '1.585968325327e+12',
#   2018,
#   12767.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f0b955807b29856175ac)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce0)',
#   None,
#   '1.585968356162e+12',
#   '1.585968356162e+12',
#   2012,
#   40199.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f0b955807b29856175ac)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce1)',
#   None,
#   '1.585968401983e+12',
#   '1.585968627698e+12',
#   2005,
#   20192.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f0b955807b29856175ac)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce2)',
#   None,
#   '1.585968466051e+12',
#   '1.585968597226e+12',
#   2018,
#   469455.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f18555807b29856175ae)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce3)',
#   None,
#   '1.585968475514e+12',
#   '1.585968601823e+12',
#   2018,
#   469455.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f1d855807b29856175af)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce4)',
#   None,
#   '1.585968485009e+12',
#   '1.585968559551e+12',
#   2012,
#   433236.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f18555807b29856175ae)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce5)',
#   None,
#   '1.585968492733e+12',
#   '1.585968564572e+12',
#   2012,
#   433236.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f1d855807b29856175af)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce6)',
#   None,
#   '1.58596851398e+12',
#   '1.58596864088e+12',
#   2005,
#   527405.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f18555807b29856175ae)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cce7)',
#   None,
#   '1.585968522791e+12',
#   '1.585968646195e+12',
#   2005,
#   527405.0,
#   'ObjectId(5e87eefa55807b29856175a9)',
#   'ObjectId(5e87f1d855807b29856175af)',
#   'ObjectId(5e8a985084f4b6216ec03602)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd30)',
#   None,
#   '1.585950354228e+12',
#   '1.585950354228e+12',
#   2018,
#   23418170.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd31)',
#   None,
#   '1.585950370793e+12',
#   '1.585950370793e+12',
#   2018,
#   24958091.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd32)',
#   None,
#   '1.585950384134e+12',
#   '1.585950384134e+12',
#   2018,
#   4608183.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd33)',
#   None,
#   '1.585950402095e+12',
#   '1.585950402095e+12',
#   2018,
#   140133.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd34)',
#   None,
#   '1.585950417719e+12',
#   '1.585950417719e+12',
#   2018,
#   547711.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd35)',
#   None,
#   '1.585950436604e+12',
#   '1.585950436604e+12',
#   2018,
#   361051.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd36)',
#   None,
#   '1.585950450291e+12',
#   '1.585950450291e+12',
#   2018,
#   1624.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd37)',
#   None,
#   '1.585950464081e+12',
#   '1.585950464081e+12',
#   2018,
#   1351637.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eed55807b298561734f)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd38)',
#   None,
#   '1.585950506111e+12',
#   '1.585950506111e+12',
#   2018,
#   302.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875f1355807b2985617350)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd39)',
#   None,
#   '1.585950518149e+12',
#   '1.585956429703e+12',
#   2018,
#   100000000.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875fdb55807b2985617351)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd3a)',
#   None,
#   '1.585950528581e+12',
#   '1.585950528581e+12',
#   2018,
#   3581387.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875ff155807b2985617352)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd3b)',
#   None,
#   '1.585950541142e+12',
#   '1.585950541142e+12',
#   2018,
#   1098.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87608c55807b2985617353)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd3c)',
#   None,
#   '1.585950554895e+12',
#   '1.585950554895e+12',
#   2012,
#   22233102.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e86c0ec55807b2985617343)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd3d)',
#   None,
#   '1.585950595085e+12',
#   '1.585950595085e+12',
#   2012,
#   30405045.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87516555807b2985617347)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd3e)',
#   None,
#   '1.585950605473e+12',
#   '1.585950605473e+12',
#   2012,
#   5000076.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e87517b55807b2985617348)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd3f)',
#   None,
#   '1.585950621484e+12',
#   '1.585950621484e+12',
#   2012,
#   154560.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e1655807b298561734b)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd40)',
#   None,
#   '1.585950637553e+12',
#   '1.585950637553e+12',
#   2012,
#   651692.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e3c55807b298561734c)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd41)',
#   None,
#   '1.585950649307e+12',
#   '1.585950649307e+12',
#   2012,
#   469126.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875e7455807b298561734d)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ('ObjectId(5e8a9e49db49cbe3e077cd42)',
#   None,
#   '1.585950670906e+12',
#   '1.585950670906e+12',
#   2012,
#   2476.0,
#   'ObjectId(5e87ae6555807b29856173ee)',
#   'ObjectId(5e875eb355807b298561734e)',
#   'ObjectId(5e8a989e84f4b6216ec03603)'),
#  ...]

# %%
#connection.exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5n/hwbln07s3_1514xfnszhdxxr0000gn/T/ipykernel_62300/3548541149.py in <module>
# ----> 1 connection.exit()
#
# NameError: name 'connection' is not defined

# %%
type(inventory)
# Out:
# list

# %%
type(inventory[0])
# Out:
# tuple

# %%
keys = ["_id","segment","createdAt","updatedAt","year","value","segment2","sector","customer"]

# %%
for row in inventory:
    inv2.insert_one({keys[0]:row[0],
                    keys[1]:row[1],
                    keys[2]:row[2],
                    keys[3]:row[3],
                    keys[4]:row[4],
                    keys[5]:row[5],
                    keys[6]:row[6],
                    keys[7]:row[7],
                    keys[8]:row[8]})

# %% [markdown]
# # Django

# %%
import os
import django
django.setup()
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'capdash.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from api.models import Segments

# %%
segs = Segments.objects.all()

# %%
seg = segs[0]
seg
# Out:
# <Segments: Residential>

# %%
[seg.name for seg in segs]
# Out:
# ['Residential', 'Imperial', 'Community']
